# %%
# !git clone https://github.com/lekshmi-j/grammar-autocorrector.git
# Out:
# fatal: destination path 'grammar-autocorrector' already exists and is not an empty directory.

# %%
# %cd grammar-autocorrector
# Out:
# /content/grammar-autocorrector

# %% [markdown]
# **Core concept 1 — Edit Distance (Levenshtein)**
# What is edit distance?
#
# Minimum number of:
#
# insertions
#
# deletions
#
# substitutions
#
# to convert word A → word B.

# %%
# !pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.12/dist-packages (0.8.4)

# %%
# from spellchecker import SpellChecker

# %%
# spell = SpellChecker()

# %%
# spell.candidates("recieve")

# %%
# def generate_candidates(word):
#     return spell.candidates(word)

# %%
# def rank_candidates(candidates):
#     """
#     Selects the best spelling candidate based on word frequency.

#     Parameters:
#     candidates (list): A list of possible corrected spellings

#     Returns:
#     str: The candidate with the highest word frequency
#     """

#     best_word = None
#     highest_frequency = -1

#     # Check each candidate word
#     for word in candidates:
#         # Get how often this word appears in language data
#         frequency = spell.word_frequency[word]

#         # Update best word if this one is more frequent
#         if frequency > highest_frequency:
#             highest_frequency = frequency
#             best_word = word

#     return best_word

# %%
# def correct_spelling_word(word):
#     if word in spell:
#         return word

#     candidates = generate_candidates(word)
#     if not candidates:
#         return word

#     return rank_candidates(candidates)

# %%
# import nltk
# nltk.download("punkt_tab")
# from nltk.tokenize import word_tokenize

# def correct_spelling_sentence(sentence):
#     tokens = word_tokenize(sentence)
#     corrected_tokens = []

#     for token in tokens:
#         if token.isalpha():
#             corrected = correct_spelling_word(token.lower())
#             corrected_tokens.append(corrected)
#         else:
#             corrected_tokens.append(token)

#     return " ".join(corrected_tokens)

# %%
from src.spelling import correct_spelling_sentence

print(correct_spelling_sentence("I recieve many mesages"))
print(correct_spelling_sentence("He go to mrket yesterday"))
# Out:
# i receive many messages
# he go to market yesterday

# %%
from src.corrector import correct_sentence
print(correct_sentence("He go to mrket yesterday"))
# Out:
# he gos to market yesterday
