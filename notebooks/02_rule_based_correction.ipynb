# %%
# !git clone https://github.com/lekshmi-j/grammar-autocorrector.git
# Out:
# Cloning into 'grammar-autocorrector'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 29 (delta 8), reused 22 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 27.85 KiB | 3.98 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# %cd grammar-autocorrector
# Out:
# /content/grammar-autocorrector/grammar-autocorrector

# %%
from src.rules import subject_verb_agreement_rule
import spacy

nlp = spacy.load("en_core_web_sm")

sentence = "He go to market"
doc = nlp(sentence)

print(subject_verb_agreement_rule(doc))
# Out:
# None
